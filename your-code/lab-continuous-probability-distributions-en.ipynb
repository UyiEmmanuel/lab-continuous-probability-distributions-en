# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
# your code here
def generate_uniform_random_numbers(bottom, ceiling, count):
    return np.random.uniform(bottom, ceiling, count)

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
uniform_data_1 = generate_uniform_random_numbers(10, 15, 100)
uniform_data_2 = generate_uniform_random_numbers(10, 60, 1000)

# %%
# your code here
# Plotting the histograms
plt.figure(figsize=(14, 6))

# %%
# your code here
plt.subplot(1, 2, 1)
plt.hist(uniform_data_1, bins=10, edgecolor='black')
plt.title('Uniform Distribution (10, 15, 100)')
plt.xlabel('Value')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
plt.hist(uniform_data_2, bins=10, edgecolor='black')
plt.title('Uniform Distribution (10, 60, 1000)')
plt.xlabel('Value')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
#Analysis of the Distributions
The first histogram (bottom=10, ceiling=15, count=100) is spread over a smaller range (10 to 15) and has fewer samples (100).
The second histogram (bottom=10, ceiling=60, count=1000) covers a larger range (10 to 60) and has more samples (1000),
resulting in a more granular and spread-out distribution.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
# your code here
def generate_normal_random_numbers(mean, std_dev, count):
    return np.random.normal(mean, std_dev, count)
normal_data_1 = generate_normal_random_numbers(10, 1, 1000)
normal_data_2 = generate_normal_random_numbers(10, 50, 1000)

# %%
# your code here
# Plotting the histograms
plt.figure(figsize=(14, 6))

# %%
# your code here
plt.subplot(1, 2, 1)
plt.hist(normal_data_1, bins=30, edgecolor='black')
plt.title('Normal Distribution (mean=10, std_dev=1, count=1000)')
plt.xlabel('Value')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
plt.hist(normal_data_2, bins=30, edgecolor='black')
plt.title('Normal Distribution (mean=10, std_dev=50, count=1000)')
plt.xlabel('Value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# your code here
plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# #Your answer here
# Analysis of the Distributions
#
# The first histogram (mean=10, std_dev=1, count=1000) has a narrow peak around the mean (10) with most values falling within the range of 9 to 11.
# The second histogram (mean=10, std_dev=50, count=1000) has a much wider spread due to the larger standard deviation, resulting in a flatter and more spread-out distribution.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
# your code here
vehicles = pd.read_csv('vehicles.csv')

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
plt.figure(figsize=(18, 6))

# %%
# your code here
plt.subplot(1, 3, 1)
plt.hist(vehicles['Fuel Barrels/Year'], bins=30, edgecolor='black')
plt.title('Fuel Barrels/Year')
plt.xlabel('Value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
plt.figure(figsize=(18, 6))

# %%
# your code here
plt.subplot(1, 3, 2)
plt.hist(vehicles['CO2 Emission Grams/Mile'], bins=30, edgecolor='black')
plt.title('CO2 Emission Grams/Mile')
plt.xlabel('Value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
plt.figure(figsize=(18, 6))

# %%
# your code here
plt.subplot(1, 3, 3)
plt.hist(vehicles['Combined MPG'], bins=30, edgecolor='black')
plt.title('Combined MPG')
plt.xlabel('Value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# your code here
plt.tight_layout()
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
def generate_exponential_random_numbers(scale, count):
    return np.random.exponential(scale, count)

# Generate the random numbers
exponential_data_1 = generate_exponential_random_numbers(10, 10)
exponential_data_2 = generate_exponential_random_numbers(10, 100)

# Plotting the histograms
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.hist(exponential_data_1, bins=10, edgecolor='black')
plt.title('Exponential Distribution (scale=10, count=10)')
plt.xlabel('Value')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
plt.hist(exponential_data_2, bins=100, edgecolor='black')
plt.title('Exponential Distribution (scale=10, count=100)')
plt.xlabel('Value')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your code here
from scipy.stats import expon

# Parameters
scale = 10  # Mean is 10 minutes

# Probability that a customer will spend less than 15 minutes
prob_less_than_15 = expon.cdf(15, scale=scale)
print(f"Probability that a customer will spend less than 15 minutes: {prob_less_than_15:.4f}")
# Out:
# Probability that a customer will spend less than 15 minutes: 0.7769

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your code here
# Probability that a customer will spend more than 15 minutes
prob_more_than_15 = 1 - prob_less_than_15
print(f"Probability that a customer will spend more than 15 minutes: {prob_more_than_15:.4f}")
# Out:
# Probability that a customer will spend more than 15 minutes: 0.2231
